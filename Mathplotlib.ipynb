# %% [markdown]
# <a href="https://colab.research.google.com/github/arshiafreen090/Libraries_python/blob/main/Mathplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Mathplotlib

# %% [markdown]
# ### Types of Data
#
# - Numerical Data
# - Categorical Data

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### 2D line plot

# %% [markdown]
# - Bivariate Analysis
# - categorical -> numerical and numerical -> numerical
# - Use case - Time series data

# %%
# plotting a simple function
price = [48000,54000,57000,49000,47000,45000]
year = [2015,2016,2017,2018,2019,2020]

plt.plot(year,price)
plt.grid()

# %%
batsman= pd.read_csv('/content/sharma-kohli.csv')
batsman
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %%
# from a pandas dataframe
batsman= pd.read_csv('/content/sharma-kohli.csv')
batsman

plt.plot(batsman['index'],batsman['V Kohli'])  #plt.plot(x[col],y[col])
plt.grid()

# %%
# plotting multiple plots
plt.plot(batsman['index'],batsman['V Kohli'])
plt.plot(batsman['index'],batsman['RG Sharma'])
plt.grid()

# %%
# labels title
plt.plot(batsman['index'],batsman['V Kohli'])
plt.plot(batsman['index'],batsman['RG Sharma'])

plt.title('Rohit Sharma Vs Virat Kohli Career Comparison')
plt.xlabel('Year')
plt.ylabel('Runs')
plt.grid()

# %%
from ipywidgets import Label
batsman= pd.read_csv('/content/sharma-kohli.csv')
batsman

plt.plot(batsman['index'],batsman['V Kohli'])  #plt.plot(x[col],y[col])
plt.grid()
# colors(hex) and line(width and style) and marker(size)
plt.plot(batsman['index'],batsman['V Kohli'],color= '#D9F10F',linestyle='solid',linewidth=3,marker='o',label='Virat')
plt.plot(batsman['index'],batsman['RG Sharma'],color='#FC00D6',linestyle='dashdot',linewidth=2,marker='D', label="rohit")
plt.title('Rohit Sharma Vs Virat Kohli Career Comparison')
plt.xlabel('Season')
plt.ylabel('Runs Scored')

plt.legend()

# %%
# limiting axes
price = [48000,54000,57000,49000,47000,45000,4500000]
year = [2015,2016,2017,2018,2019,2020,2021]

plt.plot(year,price)
# to solve the outliers
plt.ylim(0,75000)
plt.xlim(2017,2019)
# Out:
# (2017.0, 2019.0)

# %%
# show
# it is an explicit call to display the plot, on other platform these graphs are not visible so show() is used.

price= [30,89,32,45,32]
yr= [2010,2013,2016,2019,2021]
plt.plot(yr,price)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('Price vs Year')
plt.show()

# %% [markdown]
# ## Scatter plot
#
#
# *   Bivariate Analysis
# *   Numerical vs Numerical
# *   use case= finding corelation

# %% [markdown]
# we can use ```plot()```and ```scatter()```both function to plot the graph.
# but if you want to custumization and other stuff use scatter but it will be little slower than plot

# %%
# plt.scatter simple function
x= np.linspace(-10,10,50)
y= 10*x + 3 + np.random.randint(0,300,50)
plt.scatter(x,y)

# %%
# plt scatter on pandas data
df= pd.read_csv("/content/batter.csv")
df.head(50)
# Out:
#             batter  runs        avg  strike_rate
# 0          V Kohli  6634  36.251366   125.977972
# 1         S Dhawan  6244  34.882682   122.840842
# 2        DA Warner  5883  41.429577   136.401577
# 3        RG Sharma  5881  30.314433   126.964594
# 4         SK Raina  5536  32.374269   132.535312
# 5   AB de Villiers  5181  39.853846   148.580442
# 6         CH Gayle  4997  39.658730   142.121729
# 7         MS Dhoni  4978  39.196850   130.931089
# 8       RV Uthappa  4954  27.522222   126.152279
# 9       KD Karthik  4377  26.852761   129.267572
# 10       G Gambhir  4217  31.007353   119.665153
# 11       AT Rayudu  4190  28.896552   124.148148
# 12       AM Rahane  4074  30.863636   117.575758
# 13        KL Rahul  3895  46.927711   132.799182
# 14       SR Watson  3880  30.793651   134.163209
# 15       MK Pandey  3657  29.731707   117.739858
# 16       SV Samson  3526  29.140496   132.407060
# 17      KA Pollard  3437  28.404959   140.457703
# 18    F du Plessis  3403  34.373737   127.167414
# 19       YK Pathan  3222  29.290909   138.046272
# 20     BB McCullum  2882  27.711538   126.848592
# 21         RR Pant  2851  34.768293   142.550000
# 22        PA Patel  2848  22.603175   116.625717
# 23      JC Buttler  2832  39.333333   144.859335
# 24         SS Iyer  2780  31.235955   121.132898
# 25       Q de Kock  2767  31.804598   130.951254
# 26    Yuvraj Singh  2754  24.810811   124.784776
# 27        V Sehwag  2728  27.555556   148.827059
# 28        SA Yadav  2644  29.707865   134.009123
# 29         M Vijay  2619  25.930693   118.614130
# 30       RA Jadeja  2502  26.617021   122.108346
# 31       SPD Smith  2495  34.652778   124.812406
# 32        SE Marsh  2489  39.507937   130.109775
# 33       DA Miller  2455  36.102941   133.569097
# 34       JH Kallis  2427  28.552941   105.936272
# 35         WP Saha  2427  25.281250   124.397745
# 36        DR Smith  2385  28.392857   132.279534
# 37      MA Agarwal  2335  22.669903   129.506378
# 38    SR Tendulkar  2334  33.826087   114.187867
# 39      GJ Maxwell  2320  25.494505   147.676639
# 40          N Rana  2181  27.961538   130.053667
# 41        R Dravid  2174  28.233766   113.347237
# 42   KS Williamson  2105  36.293103   123.315759
# 43        AJ Finch  2092  24.904762   123.349057
# 44    AC Gilchrist  2069  27.223684   133.054662
# 45      AD Russell  2039  29.985294   168.234323
# 46       JP Duminy  2029  39.784314   120.773810
# 47      MEK Hussey  1977  38.764706   119.963592
# 48       HH Pandya  1972  29.878788   140.256046
# 49    Shubman Gill  1900  32.203390   122.186495

# %%
plt.scatter(df['avg'],df['strike_rate'], color='red', marker='o')
plt.title('Avg vs Strike Rate')
plt.xlabel('Avg')
plt.ylabel('Strike Rate')
plt.xlim(25,45)
# Out:
# (25.0, 45.0)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# size of the point
tips= sns.load_dataset('tips')
# slower scatter()
plt.scatter(tips['total_bill'],tips['tip'],s=tips['size']*20)
# scatterplot using plt.plot
# faster
plt.plot(tips['total_bill'],tips['tip'],'o')

# %% [markdown]
# ## Bar Chart

# %% [markdown]
# - Bivariate Analysis
# - Numerical vs Categorical
# - Use case - Aggregate analysis of groups

# %%
# simple bar chart (default)
children= [10,20,30,40,50]
colors= ['red','pink','blue','black','yellow']
plt.bar(colors, children, color=colors)
# Out:
# <BarContainer object of 5 artists>

# %%
# horizental bargraph
children= [10,20,30,40,50]
colors= ['red','pink','blue','black','yellow']
plt.barh(colors, children, color=colors)
# Out:
# <BarContainer object of 5 artists>

# %%
# color and label
df= pd.read_csv('/content/batsman_season_record.csv')
df
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
plt.bar(np.arange(df.shape[0])-0.2,df["2015"],width=0.2, color='#f777c6')
plt.bar(np.arange(df.shape[0]),df["2016"],width=0.2, color='#7f77f7')
plt.bar(np.arange(df.shape[0])+0.2,df["2017"],width=0.2, color='#abf56e')

plt.xticks(np.arange(df.shape[0]),df['batsman'])
plt.title('bar graph of batsman')
plt.xlabel('batsman')
plt.ylabel('runs')
plt.show()

# %%
children= [10,20,30,40,50]
colors= ['#f2464f','#de7ceb','#72b6ed','#0b0c0d','#e1e693']
plt.xticks(np.arange(len(children)),['red red red red ','pink pink pink pink','blue blue blue blue','black black black black','yellow yellow yellow yellow'])
display(plt.bar(colors, children, color=colors))

# to fix this we use
# plt.xticks(rotation='vertical')
# now
plt.xticks(np.arange(len(children)),['red red red red ','pink pink pink pink','blue blue blue blue','black black black black','yellow yellow yellow yellow'], rotation='vertical')
display(plt.bar(colors, children, color=colors))
# Out:
# <BarContainer object of 5 artists>
# <BarContainer object of 5 artists>

# %%
# stacked Bar graph

# Base layer for 2017 (pink)
plt.bar(df['batsman'], df['2017'], color='#f777c6', label='2017')

# Stack 2016 on top of 2017 (purple)
plt.bar(df['batsman'], df['2016'], bottom=df['2017'], color='#7f77f7', label='2016')

# Stack 2015 on top of (2016 + 2017) (light green)
plt.bar(df['batsman'], df['2015'], bottom=df['2016'] + df['2017'], color='#94e3ab', label='2015')
plt.legend()
plt.show()

# %% [markdown]
# ## Histogram

# %% [markdown]
# - Univariate Analysis
# - Numerical col
# - Use case - Frequency Count

# %%
# simple histogram
data= [1,1,2,2,2,2,2,4,8,13,13,13,19]
plt.hist(data)
# Out:
# (array([7., 1., 0., 1., 0., 0., 3., 0., 0., 1.]),
#  array([ 1. ,  2.8,  4.6,  6.4,  8.2, 10. , 11.8, 13.6, 15.4, 17.2, 19. ]),
#  <BarContainer object of 10 artists>)

# %%
# logarithmic scale
arr = np.load('/content/big-array.npy')
plt.hist(arr,bins=[10,20,30,40,50,60,70],log=True)
plt.show()

# %% [markdown]
# ## Pie chart

# %% [markdown]
# - Univariate/Bivariate Analysis
# - Categorical vs numerical
# - Use case - To find contibution on a standard scale

# %%
# simple data \
data =[10,20,30,40,50]
subjects= ['English','Maths','Science','Social','Hindi']
plt.pie(data,labels=subjects)
plt.show()

# %%
# dataset
df = pd.read_csv('/content/gayle-175.csv')
df
plt.pie(df['batsman_runs'], labels=df['batsman'],autopct='%1.1f%%')
plt.show()

# %%
# explode shadow
plt.pie(df['batsman_runs'],labels=df['batsman'],autopct='%0.1f%%',explode=[0.3,0,0,0,0,0.1],shadow=True)
plt.show()

# %% [markdown]
# ## Changing styles

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# can use any one of them

# %% [markdown]
# ### Colored Scatterplots

# %%
iris= pd.read_csv('/content/iris.csv')
iris
iris.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 40    41            5.0           3.5            1.3           0.3
# 50    51            7.0           3.2            4.7           1.4
# 34    35            4.9           3.1            1.5           0.1
# 128  129            6.4           2.8            5.6           2.1
# 37    38            4.9           3.1            1.5           0.1
#
#              Species
# 40       Iris-setosa
# 50   Iris-versicolor
# 34       Iris-setosa
# 128   Iris-virginica
# 37       Iris-setosa

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# coloured scatter plot with cmap and alpha
iris["Species"]= iris["Species"].replace("Iris-setosa","0")
iris["Species"]= iris["Species"].replace("Iris-versicolor","1")
iris["Species"]= iris["Species"].replace("Iris-virginica","2")
iris["Species"] = iris["Species"].astype(int) # Convert to integer type
print(iris)
plt.scatter(iris["SepalLengthCm"],iris["PetalLengthCm"],c=iris["Species"],cmap='jet',alpha=0.7)
plt.colorbar()
plt.xlabel("SepalLengthCm")
plt.ylabel("PetalLengthCm")
plt.show()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %% [markdown]
# ## Plot size

# %%
plt.figure(figsize=(10,5))

plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='jet',alpha=0.7)
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.colorbar()

# %% [markdown]
# ## Annotation

# %%
batters= pd.read_csv('batter.csv')
batters= batters.head(25)
batters
# Out:
#             batter  runs        avg  strike_rate
# 0          V Kohli  6634  36.251366   125.977972
# 1         S Dhawan  6244  34.882682   122.840842
# 2        DA Warner  5883  41.429577   136.401577
# 3        RG Sharma  5881  30.314433   126.964594
# 4         SK Raina  5536  32.374269   132.535312
# 5   AB de Villiers  5181  39.853846   148.580442
# 6         CH Gayle  4997  39.658730   142.121729
# 7         MS Dhoni  4978  39.196850   130.931089
# 8       RV Uthappa  4954  27.522222   126.152279
# 9       KD Karthik  4377  26.852761   129.267572
# 10       G Gambhir  4217  31.007353   119.665153
# 11       AT Rayudu  4190  28.896552   124.148148
# 12       AM Rahane  4074  30.863636   117.575758
# 13        KL Rahul  3895  46.927711   132.799182
# 14       SR Watson  3880  30.793651   134.163209
# 15       MK Pandey  3657  29.731707   117.739858
# 16       SV Samson  3526  29.140496   132.407060
# 17      KA Pollard  3437  28.404959   140.457703
# 18    F du Plessis  3403  34.373737   127.167414
# 19       YK Pathan  3222  29.290909   138.046272
# 20     BB McCullum  2882  27.711538   126.848592
# 21         RR Pant  2851  34.768293   142.550000
# 22        PA Patel  2848  22.603175   116.625717
# 23      JC Buttler  2832  39.333333   144.859335
# 24         SS Iyer  2780  31.235955   121.132898

# %%
# naming the scatter points in the graph

plt.figure(figsize=(15,10))
plt.scatter(batters["avg"],batters["strike_rate"] )

for i in range(batters.shape[0]):

  plt.text(batters['avg'].values[i],batters['strike_rate'].values[i],batters['batter'].values[i])
  # plt.text(x,y,"name")

# %% [markdown]
# ## Horizental and vertical Line

# %%
plt.figure(figsize=(15,10))

plt.scatter(batters['avg'], batters['strike_rate'])
plt.axhline(130,color='red')
plt.axhline(140,color='green')
plt.axvline(30,color='red')

for i in range(batters.shape[0]):
  plt.text(batters['avg'].values[i], batters['strike_rate'].values[i], batters['batter'].values[i])

# %% [markdown]
# ## Subplots

# %% [markdown]
# - fig= one whole graph where all the differnt graph(ax) inside
# - ax= differnt graphs in one fig

# %%
fig,ax= plt.subplots(nrows=2,ncols=1,figsize=(10,10))
batters= pd.read_csv('/content/batter.csv')

ax[0].scatter(batters['avg'],batters['strike_rate'],color='#7f77f7')
ax[1].scatter(batters['avg'],batters['runs'])
ax[0].set_title('Avg Vs Strike Rate')
ax[0].set_ylabel('Strike Rate')


ax[1].set_title('Avg Vs Runs')
ax[1].set_ylabel('Runs')
ax[1].set_xlabel('Avg')
# Out:
# Text(0.5, 0, 'Avg')

# %%
fig, ax= plt.subplots(nrows=2,ncols=2,figsize=(10,10))
ax[0,0].scatter(batters['avg'],batters['strike_rate'],color='#7f77f7')
ax[0,1].scatter(batters['avg'],batters['runs'])
ax[1,0].hist(batters['avg'])
ax[1,1].hist(batters['runs'])
# Out:
# (array([499.,  40.,  19.,  19.,   9.,   6.,   4.,   4.,   3.,   2.]),
#  array([   0. ,  663.4, 1326.8, 1990.2, 2653.6, 3317. , 3980.4, 4643.8,
#         5307.2, 5970.6, 6634. ]),
#  <BarContainer object of 10 artists>)

# %%
fig = plt.figure()

ax1 = fig.add_subplot(2,2,1)
ax1.scatter(batters['avg'],batters['strike_rate'],color='red')

ax2 = fig.add_subplot(2,2,2)
ax2.hist(batters['runs'])

ax3 = fig.add_subplot(2,2,3)
ax3.hist(batters['avg'])
# Out:
# (array([102., 125., 103.,  82.,  78.,  43.,  22.,  14.,   2.,   1.]),
#  array([ 0.        ,  5.56666667, 11.13333333, 16.7       , 22.26666667,
#         27.83333333, 33.4       , 38.96666667, 44.53333333, 50.1       ,
#         55.66666667]),
#  <BarContainer object of 10 artists>)

# %%
fig = plt.figure(figsize=(12,8))

ax = plt.subplot(projection='3d')

# Define x, y, and create meshgrid for xx, yy, and a sample z
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
xx, yy = np.meshgrid(x, y)
z = np.sin(np.sqrt(xx**2 + yy**2)) # Example: a simple 3D surface

p = ax.plot_surface(xx,yy,z,cmap='viridis')
fig.colorbar(p)
plt.show() # Added plt.show() to explicitly display the plot
