# %% [markdown]
# <a href="https://colab.research.google.com/github/arshiafreen090/Libraries_python/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Seaborn**

# %% [markdown]
# ### Why Seaborn?
#
# - provides a layer of abstraction hence simpler to use
# - better aesthetics
# - more graphs included

# %% [markdown]
# ## Seaborn Plot Categories
#
# ### 1. Relational
# - `sns.scatterplot()`
# - `sns.lineplot()`
#
# ### 2. Distribution
# - `sns.histplot()`
# - `sns.kdeplot()`
# - `sns.rugplot()`
#
# ### 3. Categorical
# - `sns.barplot()`
# - `sns.countplot()`
# - `sns.boxplot()`
# - `sns.violinplot()`
# - `sns.swarmplot()`
#
# ### 4. Matrix
# - `sns.heatmap()`
# - `sns.clustermap()`
#
# ### 5. Regression
# - `sns.regplot()`
# - `sns.lmplot()`
#
# ### 6. Multiple / Figure-Level
# - `sns.jointplot()`
# - `sns.pairplot()`
# - `sns.relplot()`
# - `sns.displot()`
# - `sns.catplot()`
#
# ### Axes-Level vs Figure-Level
#
# **Axes-Level:**
# `scatterplot()`, `lineplot()`, `histplot()`, `kdeplot()`, `barplot()`, `boxplot()`, `regplot()` etc.
#
# **Figure-Level:**
# `relplot()`, `displot()`, `catplot()`, `lmplot()`, `jointplot()`, `pairplot()`

# %% [markdown]
# ### 1. Relational Plot
#
# - to see the statistical relation between 2 or more variables.
# - Bivariate Analysis
#
# Plots under this section
#
# - scatterplot
# - lineplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
tips= sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
#  `plt.scatter()` vs `sns.relplot()`
#
# - `sns.relplot()` → it control over the whole fig whereas `plt.scatter()` controls only on axes thats why its legend inside the box.
# - `plt.scatter()` → Creates a simple scatter plot.
# - `sns.relplot()` → Shows relationships between variables. also it is very custmizatiable.
# - `relplot()` supports both **scatter and line plots** using `kind`.
# - `relplot()` makes grouping easy using `hue`, `row`, and `col`.

# %% [markdown]
#  Axes-Level Functions
# - `sns.scatterplot()` → Creates a scatter plot
# - `sns.lineplot()` → Creates a line plot
#
#  Figure-Level Functions
# - `sns.relplot()` → High-level relationship plot
#   - `kind="scatter"` → Scatter plot
#   - `kind="line"` → Line plot
#
# **Easy way to remember:**
#
# Axes-level → `scatterplot()`, `lineplot()`
#
# Figure-level → `relplot()`

# %%
# scatter plot ---> axes level function
plt.figure(figsize=(5,6))
sns.scatterplot(data=tips,x='total_bill', y='tip', hue='sex',style='time',size='size')
plt.show()

# %%
# relplot -> figure level -> square shape
sns.relplot(data=tips, x='total_bill', y='tip', kind='scatter',hue='sex',style='time',size='size')

# %%
# lineplot
gap=px.data.gapminder()
temp_gap= gap[gap['country']== 'India']
temp_gap
# Out:
#     country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 696   India      Asia  1952   37.373   372000000   546.565749       IND
# 697   India      Asia  1957   40.249   409000000   590.061996       IND
# 698   India      Asia  1962   43.605   454000000   658.347151       IND
# 699   India      Asia  1967   47.193   506000000   700.770611       IND
# 700   India      Asia  1972   50.651   567000000   724.032527       IND
# 701   India      Asia  1977   54.208   634000000   813.337323       IND
# 702   India      Asia  1982   56.596   708000000   855.723538       IND
# 703   India      Asia  1987   58.553   788000000   976.512676       IND
# 704   India      Asia  1992   60.223   872000000  1164.406809       IND
# 705   India      Asia  1997   61.765   959000000  1458.817442       IND
# 706   India      Asia  2002   62.879  1034172547  1746.769454       IND
# 707   India      Asia  2007   64.698  1110396331  2452.210407       IND
#
#      iso_num
# 696      356
# 697      356
# 698      356
# 699      356
# 700      356
# 701      356
# 702      356
# 703      356
# 704      356
# 705      356
# 706      356
# 707      356

# %%
# axes level function
sns.lineplot(data=temp_gap, x='year', y='lifeExp')
plt.show()

# %%
# using relplot
sns.relplot(data=temp_gap,x='year',y='lifeExp', kind='line')

# %%
# hue --> style
temp_df= gap[gap['country'].isin(['India','Brazil','Japan'])]
temp_df
# Out:
#     country continent  year  lifeExp         pop     gdpPercap iso_alpha  \
# 168  Brazil  Americas  1952   50.917    56602560   2108.944355       BRA
# 169  Brazil  Americas  1957   53.285    65551171   2487.365989       BRA
# 170  Brazil  Americas  1962   55.665    76039390   3336.585802       BRA
# 171  Brazil  Americas  1967   57.632    88049823   3429.864357       BRA
# 172  Brazil  Americas  1972   59.504   100840058   4985.711467       BRA
# 173  Brazil  Americas  1977   61.489   114313951   6660.118654       BRA
# 174  Brazil  Americas  1982   63.336   128962939   7030.835878       BRA
# 175  Brazil  Americas  1987   65.205   142938076   7807.095818       BRA
# 176  Brazil  Americas  1992   67.057   155975974   6950.283021       BRA
# 177  Brazil  Americas  1997   69.388   168546719   7957.980824       BRA
# 178  Brazil  Americas  2002   71.006   179914212   8131.212843       BRA
# 179  Brazil  Americas  2007   72.390   190010647   9065.800825       BRA
# 696   India      Asia  1952   37.373   372000000    546.565749       IND
# 697   India      Asia  1957   40.249   409000000    590.061996       IND
# 698   India      Asia  1962   43.605   454000000    658.347151       IND
# 699   India      Asia  1967   47.193   506000000    700.770611       IND
# 700   India      Asia  1972   50.651   567000000    724.032527       IND
# 701   India      Asia  1977   54.208   634000000    813.337323       IND
# 702   India      Asia  1982   56.596   708000000    855.723538       IND
# 703   India      Asia  1987   58.553   788000000    976.512676       IND
# 704   India      Asia  1992   60.223   872000000   1164.406809       IND
# 705   India      Asia  1997   61.765   959000000   1458.817442       IND
# 706   India      Asia  2002   62.879  1034172547   1746.769454       IND
# 707   India      Asia  2007   64.698  1110396331   2452.210407       IND
# 792   Japan      Asia  1952   63.030    86459025   3216.956347       JPN
# 793   Japan      Asia  1957   65.500    91563009   4317.694365       JPN
# 794   Japan      Asia  1962   68.730    95831757   6576.649461       JPN
# 795   Japan      Asia  1967   71.430   100825279   9847.788607       JPN
# 796   Japan      Asia  1972   73.420   107188273  14778.786360       JPN
# 797   Japan      Asia  1977   75.380   113872473  16610.377010       JPN
# 798   Japan      Asia  1982   77.110   118454974  19384.105710       JPN
# 799   Japan      Asia  1987   78.670   122091325  22375.941890       JPN
# 800   Japan      Asia  1992   79.360   124329269  26824.895110       JPN
# 801   Japan      Asia  1997   80.690   125956499  28816.584990       JPN
# 802   Japan      Asia  2002   82.000   127065841  28604.591900       JPN
# 803   Japan      Asia  2007   82.603   127467972  31656.068060       JPN
#
#      iso_num
# 168       76
# 169       76
# 170       76
# 171       76
# 172       76
# 173       76
# 174       76
# 175       76
# 176       76
# 177       76
# 178       76
# 179       76
# 696      356
# 697      356
# 698      356
# 699      356
# 700      356
# 701      356
# 702      356
# 703      356
# 704      356
# 705      356
# 706      356
# 707      356
# 792      392
# 793      392
# 794      392
# 795      392
# 796      392
# 797      392
# 798      392
# 799      392
# 800      392
# 801      392
# 802      392
# 803      392

# %%
sns.relplot(data=temp_df,x='year',y='lifeExp', kind='line',hue='country',style='country')

# %%
# facet plot -> figure level function -> work with relplot
# it will not work with scatterplot and lineplot

sns.relplot(data=tips,x='total_bill',y='tip',col='time',hue='sex',kind='scatter')

# %%
# col wrap
sns.relplot(data=gap, x='lifeExp', y='gdpPercap', kind='scatter', col='year', col_wrap=3)

# %% [markdown]
# ### 2. Distribution Plots
#
# - used for univariate analysis
# - used to find out the distribution
# - Range of the observation
# - Central Tendency
# - is the data bimodal?
# - Are there outliers?
#
# Plots under distribution plot
#
# - histplot
# - kdeplot
# - rugplot

# %%
# figure level -> displot
# axes level -> histplot -> kdeplot -> rugplot

# %%
# plotting univariate histogram
sns.histplot(data=tips, x='total_bill')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# bins parameter
sns.displot(data=tips,x='total_bill',kind='hist',bins=2)

# %%
# hue
sns.displot(data=tips,x='total_bill',kind='hist',hue='sex')

# %%
# element---> step
sns.displot(data=tips, x='tip', kind='hist',hue='sex',element='step')

# %%
titanic= sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
sns.displot(data=titanic,x="age", hue="sex",kind="hist", element="step")

# %%
#  faceting using col and row -> not work on histplot function
sns.displot(data=tips, x='tip', kind='hist',col='sex',element='step', color='purple')

# %%
# kdplot
# Rather than using discrete bins, a KDE plot smooths the observations with a Gaussian kernel, producing a continuous density estimate
sns.displot(data=tips, x='total_bill', kind='kde')
plt.title('density vs total bill')
# Out:
# Text(0.5, 1.0, 'density vs total bill')

# %%
# hue---> fill
sns.displot(data=tips, x='total_bill', kind='kde',hue='sex',fill=True)

# %%
# Rugplot

# Plot marginal distributions by drawing ticks along the x and y axes.

# This function is intended to complement other plots by showing the location of individual observations in an unobtrusive way.
sns.kdeplot(data=tips,x='total_bill')
sns.rugplot(data=tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# Bivariate histogram
# A bivariate histogram bins the data within rectangles that tile the plot
# and then shows the count of observations within each rectangle with the fill color
sns.displot(data=tips, x='total_bill', y='tip',kind='hist')
# here x and y both are given

# %%
# Bivariate Kdeplot
# a bivariate KDE plot smoothes the (x, y) observations with a 2D Gaussian
sns.kdeplot(data=tips, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### 3. Matrix Plot
#
# - Heatmap
# - Clustermap

# %%
# Heatmap

# Plot rectangular data as a color-encoded matrix
plt.figure(figsize=(10,10))
temp_df= gap.pivot(index='country', columns='year',values='lifeExp')
sns.heatmap(temp_df)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
# annot
temp_df = gap[gap['continent'] == 'Europe'].pivot(index='country',columns='year',values='lifeExp')

plt.figure(figsize=(10,10))
sns.heatmap(temp_df,annot=True,linewidth=0.5, cmap='summer')
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
# Clustermap

# Plot a matrix dataset as a hierarchically-clustered heatmap.

# This function requires scipy to be available.

iris = px.data.iris()
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# 145           3
# 146           3
# 147           3
# 148           3
# 149           3
#
# [150 rows x 6 columns]

# %%
plt.figure(figsize=(10,10))
sns.clustermap(iris.iloc[:,[0,1,2,3]])

# %% [markdown]
# ### 4. Categorical Plots
#
# ### Categorical Scatter Plot
#
# - Stripplot
# - Swarmplot
#
# ### Categorical Distribution Plots
#
# - Boxplot
# - Violinplot
#
# ### Categorical Estimate Plot -> for central tendency
#
# - Barplot
# - Pointplot
# - Countplot
#
# ### Figure level function -> `catplot`

# %%
# boxplot

# %% [markdown]
# A boxplot is a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile [Q1], median, third quartile [Q3] and “maximum”). It can tell you about your outliers and what their values are. Boxplots can also tell you if your data is symmetrical, how tightly your data is grouped and if and how your data is skewed.

# %%
sns.boxplot(data=tips,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips, x='day', y='total_bill', hue='sex')
plt.title('Total Bill Distribution by Day and Sex')
plt.show()

# %%
# Using catplot
sns.catplot(data=tips,x='day',y='total_bill',kind='box')

# %%
# single boxplot -> numerical col
sns.boxplot(data=tips,y='total_bill')
# Out:
# <Axes: ylabel='total_bill'>

# %% [markdown]
#  Violinplot = (Boxplot + KDEplot)

# %%
# violinplot
sns.violinplot(data=tips,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# barplot
# some issue with errorbar
import numpy as np
sns.barplot(data=tips, x='sex', y='total_bill',hue='smoker',estimator=np.min)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(data=tips, x='sex', y='total_bill',ci=None)
# Out:
# /tmp/ipykernel_4107/3522951494.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=tips, x='sex', y='total_bill',ci=None)
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# point plot
sns.pointplot(data=tips, x='sex', y='total_bill',hue='smoker',ci=None)
# Out:
# /tmp/ipykernel_4107/2657825262.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.pointplot(data=tips, x='sex', y='total_bill',hue='smoker',ci=None)
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# countplot
sns.countplot(data=tips,x='sex',hue='day')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# pointplot

# %%
# faceting using catplot
sns.catplot(data=tips, x='sex',y='total_bill',col='smoker',kind='box',row='time')
